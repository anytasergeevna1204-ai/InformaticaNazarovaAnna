# %%
print("=" * 40)
print ("\tЗдравствуй, студент!\n", "Ты поступил в политех в 2025 году!!!" , end="\n\n"  )
print("=" * 40)
# Out:
# ...
# 	Здравствуй, студент!
#  Ты поступил в политех в 2025 году!!!
#
# ...
