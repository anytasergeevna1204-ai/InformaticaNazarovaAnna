# %%
thing_name = "Барометр"
thing_num = 27182856790732
thing_cond = "Stable"
thing_amount = 48

print(f"Название:\t{thing_name}\nИнв.номер:\t{thing_num}\nCостояние:\t{thing_cond}\nКол-во:\t\t{thing_amount}")
# Out:
# Название:	Барометр
# Инв.номер:	27182856790732
# Cостояние:	Stable
# Кол-во:		48
