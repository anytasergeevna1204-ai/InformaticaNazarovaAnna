# %%
print("Я умею делать буквы большими, введи своё слово и я покажу:")

user_input = input()
processed_input = user_input.upper()

print(user_input,processed_input, sep=(" -> "))
# Out:
# Я умею делать буквы большими, введи своё слово и я покажу:
